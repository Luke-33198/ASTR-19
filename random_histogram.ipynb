# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.random(1000)
plt.hist(x,color='pink',bins=100,label='random distribution')
plt.legend()
plt.xlabel("Numbers 0 - 1")
plt.ylabel("Frequency of numbers")
plt.savefig("rand_hist.pdf")
